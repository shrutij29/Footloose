# %% [markdown]
# ### Import Libraries ###

# %%
import os
import json
import csv
import pandas as pd
from datetime import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

# %% [markdown]
# ## Blake's code to see frame by frame ##

# %% [markdown]
# #### Body Position Info function ####

# %%
def get_body_position_info(file_name):
    '''Input a JSON file and get the body position of each person.  Outer list is
    list of people.  Inner list is x,y position of each body part for that person'''
    f = open(file_name, "r")
    j = json.load(f)
    f.close
    people= []

    for i,person in enumerate(j):
        #Set up list to collect person's body location
        person_i = []
        count = 0

        #add each body part position to the list
        for body_part in person:
            count+=1
            if count == 1: continue
            else: person_i.append(body_part[1])

        #Append entire list to list of people
        people.append(person_i)

    return people


def get_body_part_labels(file_name):
    '''Input a JSON file and get the body position of each person.  Outer list is
    list of people.  Inner list is x,y position of each body part for that person'''
    f = open(file_name, "r")
    j = json.load(f)
    f.close
    body_part_labels= []
   
    for i,body_part in enumerate(j[0]):
            if i == 0: continue
            else: body_part_labels.append(body_part[0])

    return body_part_labels

# %%
body_part_labels = get_body_part_labels('./densepose/txt/ballet/-5Yp-vToI2E_016_0001.json')
people = get_body_position_info('./densepose/txt/ballet/-5Yp-vToI2E_016_0002.json')
people[0]
# Out:
# [[417.4290771484375, 171.84947204589844],
#  [429.3904113769531, 162.8577117919922],
#  [417.4290771484375, 162.8577117919922],
#  [457.3002014160156, 176.84487915039062],
#  [416.4322814941406, 173.84762573242188],
#  [494.1809997558594, 236.78988647460938],
#  [404.470947265625, 233.79263305664062],
#  [561.9619140625, 295.7358093261719],
#  [358.619140625, 271.7578125],
#  [480.2261047363281, 319.71380615234375],
#  [432.3807373046875, 304.7275695800781],
#  [483.2164306640625, 354.6817321777344],
#  [425.4032897949219, 353.6826477050781],
#  [520.0972290039062, 433.6093444824219],
#  [368.5869140625, 451.59283447265625],
#  [494.1809997558594, 578.4764404296875],
#  [426.4000549316406, 537.5140380859375]]

# %%
#Hardcode dictionary of connections:
connections_dict = {}
connections_dict['left_shoulder'] = 'left_elbow'
connections_dict['left_elbow'] = 'left_wrist'
connections_dict['left_hip'] = 'left_knee'
connections_dict['left_knee'] = 'left_ankle'
connections_dict['right_shoulder'] = 'right_elbow'
connections_dict['right_elbow'] = 'right_wrist'
connections_dict['right_hip'] = 'right_knee'
connections_dict['right_knee'] = 'right_ankle'
connections_dict['left_ear'] = 'left_eye'
connections_dict['left_eye'] = 'nose'
connections_dict['nose'] = 'right_eye'
connections_dict['right_eye'] = 'right_ear'

# %%
#Create body part index dictionary for easy acces to index of each body part
body_part_indx_dict = {}
indexes = list(range(len(body_part_labels)))
for i in range(len(body_part_labels)):
    body_part_indx_dict[body_part_labels[i]] = indexes[i]

body_part_indx_dict
# Out:
# {'nose': 0,
#  'left_eye': 1,
#  'right_eye': 2,
#  'left_ear': 3,
#  'right_ear': 4,
#  'left_shoulder': 5,
#  'right_shoulder': 6,
#  'left_elbow': 7,
#  'right_elbow': 8,
#  'left_wrist': 9,
#  'right_wrist': 10,
#  'left_hip': 11,
#  'right_hip': 12,
#  'left_knee': 13,
#  'right_knee': 14,
#  'left_ankle': 15,
#  'right_ankle': 16}

# %% [markdown]
# #### Plot Body Positions function ####

# %%
def plot_body_positions(list_of_people, figsize = (8,4)):
    plt.figure(figsize=figsize)
    cmap = plt.cm.get_cmap('tab10').colors*2 #*2 for when there's >10 ppl/image
    #cmap = cmap + cmap # Get the tab10 colormap
    for i,person in enumerate(list_of_people):
        #separate x and y information into lists
        x_values = [point[0] for point in person]
        y_values = [point[1] for point in person]
        y_values = [800 - i for i in y_values] #Invert x due to skeleton data structure

        #Plot the connections between joints
        for k,v in connections_dict.items():
            temp_x = [x_values[body_part_indx_dict[k]], x_values[body_part_indx_dict[v]]]
            temp_y = [y_values[body_part_indx_dict[k]], y_values[body_part_indx_dict[v]]]
            plt.plot(temp_x, temp_y, linewidth = 4, color = cmap[i])

        #Plot the scatter data and label figure
        plt.scatter(x_values, y_values, label=f'Person {i}', color = cmap[i])
        plt.xlabel('X position')
        plt.ylabel('Y position')
        plt.title('Scatter plot of body positions in X-Y space')
    plt.legend(loc = 'upper left', fontsize = 'small')
    plt.show()

# %%
people = get_body_position_info('./densepose/txt/ballet/-5Yp-vToI2E_016_0001.json')
plot_body_positions(people, figsize=(6,3))

# %% [markdown]
# #### Test Multiple Frames ####

# %%
directory = './densepose/txt'

#get directories without hidden files
directories = [d for d in os.listdir(directory) if os.path.isdir(os.path.join(directory, d))]
directories.sort()

#Setup dictionary to collect file names
all_file_names = {}

#Identify all file names
for d in directories:
    #get file names without hidden files
    files = [f for f in os.listdir(os.path.join(directory, d)) if os.path.isfile(os.path.join(directory, d, f))]
    files.sort()
    all_file_names[d] = files

# %%
first_img_indexes = {}

for d in directories:
    num_images = len(all_file_names[d])
    img_count = 0
    first_images = []
    for i in range(num_images):
        if all_file_names[d][i].split('.')[0].split('_')[-1] == '0001':
            first_images.append(img_count)
            #img_count = 0
        img_count += 1
    first_img_indexes[d] = first_images

all_file_names['ballet'][386]
# Out:
# '0aUhNK8tJPU_035_0001.json'

# %%
#Explore preliminary data
dance_type = 'ballet'

#Collect files names from specific video
video_num = 0 #Starts counting with 0
start = first_img_indexes[dance_type][video_num]
stop = first_img_indexes[dance_type][video_num + 1]
file_names = all_file_names[dance_type][start:stop]

#Plot the frames
for file in file_names[0:5]:
    print(f'Filename: {file}')
    file_path = os.path.join(directory, dance_type, file)
    people = get_body_position_info(file_path)
    plot_body_positions(people, figsize = (4,3))
# Out:
# Filename: -5Yp-vToI2E_016_0001.json
# Filename: -5Yp-vToI2E_016_0002.json
# Filename: -5Yp-vToI2E_016_0003.json
# Filename: -5Yp-vToI2E_016_0004.json
# Filename: -5Yp-vToI2E_016_0005.json

# %% [markdown]
# ## Testing Function to Swap People ##

# %% [markdown]
# #### Checking JSON file ####

# %%
# Load the JSON file
with open('./densepose/txt/ballet/-5Yp-vToI2E_016_0001.json', 'r') as f:
    dataset = json.load(f)

# %%
for person in dataset:
    print(person)
# Out:
# ['person0', ['nose', [417.8628845214844, 172.3057403564453]], ['left_eye', [428.8619079589844, 164.3126220703125]], ['right_eye', [417.8628845214844, 164.3126220703125]], ['left_ear', [456.8594665527344, 174.30401611328125]], ['right_ear', [416.8629455566406, 173.3048858642578]], ['left_shoulder', [494.85614013671875, 238.2489471435547]], ['right_shoulder', [405.8639221191406, 231.25497436523438]], ['left_elbow', [556.8507080078125, 290.2041931152344]], ['right_elbow', [359.8679504394531, 270.2214050292969]], ['left_wrist', [484.85699462890625, 317.18096923828125]], ['right_wrist', [433.8614807128906, 305.1912841796875]], ['left_hip', [483.8570861816406, 348.154296875]], ['right_hip', [423.8623352050781, 356.14739990234375]], ['left_knee', [521.853759765625, 431.0828857421875]], ['right_knee', [369.8670654296875, 452.0647888183594]], ['left_ankle', [514.8543701171875, 546.9830322265625]], ['right_ankle', [426.8620910644531, 539.9890747070312]]]
# ['person1', ['nose', [214.0703125, 171.00918579101562]], ['left_eye', [224.04739379882812, 164.01382446289062]], ['right_eye', [216.06573486328125, 164.01382446289062]], ['left_ear', [252.98094177246094, 172.00851440429688]], ['right_ear', [252.98094177246094, 172.00851440429688]], ['left_shoulder', [299.87322998046875, 230.96932983398438]], ['right_shoulder', [213.07261657714844, 232.96800231933594]], ['left_elbow', [359.7357177734375, 269.94342041015625]], ['right_elbow', [198.10699462890625, 300.9228515625]], ['left_wrist', [420.5959167480469, 298.9241638183594]], ['right_wrist', [252.98094177246094, 317.91156005859375]], ['left_hip', [292.8892517089844, 368.877685546875]], ['right_hip', [232.02906799316406, 366.8789978027344]], ['left_knee', [309.8503112792969, 475.8066101074219]], ['right_knee', [171.1688690185547, 461.81591796875]], ['left_ankle', [310.8480224609375, 588.7315673828125]], ['right_ankle', [219.05885314941406, 542.7620849609375]]]
# ['person2', ['nose', [607.5880737304688, 202.62086486816406]], ['left_eye', [617.5676879882812, 191.63803100585938]], ['right_eye', [607.5880737304688, 193.63490295410156]], ['left_ear', [644.5125732421875, 204.6177520751953]], ['right_ear', [645.5105590820312, 204.6177520751953]], ['left_shoulder', [684.4309692382812, 262.52728271484375]], ['right_shoulder', [599.6044311523438, 268.5179138183594]], ['left_elbow', [735.326904296875, 310.452392578125]], ['right_elbow', [556.692138671875, 291.4820251464844]], ['left_wrist', [666.4677124023438, 342.4024658203125]], ['right_wrist', [616.5697021484375, 326.42742919921875]], ['left_hip', [676.447265625, 388.3307189941406]], ['right_hip', [625.5513305664062, 393.3229064941406]], ['left_knee', [704.39013671875, 496.1622314453125]], ['right_knee', [584.635009765625, 482.18408203125]], ['left_ankle', [681.4370727539062, 567.0514526367188]], ['right_ankle', [657.4860229492188, 552.0748901367188]]]
# ['person3', ['nose', [787.084228515625, 201.12356567382812]], ['left_eye', [798.079345703125, 192.14019775390625]], ['right_eye', [784.0855102539062, 193.1383514404297]], ['left_ear', [824.0677490234375, 202.12171936035156]], ['right_ear', [780.0873413085938, 209.10877990722656]], ['left_shoulder', [862.0509033203125, 266.0033874511719]], ['right_shoulder', [780.0873413085938, 269.9960021972656]], ['left_elbow', [887.039794921875, 331.8813781738281]], ['right_elbow', [731.1090698242188, 311.9183349609375]], ['left_wrist', [835.0628662109375, 360.8277587890625]], ['right_wrist', [796.0802001953125, 350.84625244140625]], ['left_hip', [848.05712890625, 379.7926330566406]], ['right_hip', [795.0806274414062, 379.7926330566406]], ['left_knee', [859.0521850585938, 468.6280822753906]], ['right_knee', [766.0935668945312, 473.61883544921875]], ['left_ankle', [878.0437622070312, 557.4635620117188]], ['right_ankle', [831.0646362304688, 553.470947265625]]]
# ['person4', ['nose', [0.49827441573143005, 331.4165954589844]], ['left_eye', [0.49827441573143005, 331.4165954589844]], ['right_eye', [45.34297180175781, 431.1380920410156]], ['left_ear', [0.49827441573143005, 331.4165954589844]], ['right_ear', [0.49827441573143005, 331.4165954589844]], ['left_shoulder', [2.4913721084594727, 337.39990234375]], ['right_shoulder', [0.49827441573143005, 331.4165954589844]], ['left_elbow', [6.477567195892334, 379.2829284667969]], ['right_elbow', [9.46721363067627, 383.2717590332031]], ['left_wrist', [31.39128875732422, 412.1910095214844]], ['right_wrist', [31.39128875732422, 412.1910095214844]], ['left_hip', [0.49827441573143005, 331.4165954589844]], ['right_hip', [0.49827441573143005, 331.4165954589844]], ['left_knee', [6.477567195892334, 379.2829284667969]], ['right_knee', [2.4913721084594727, 337.39990234375]], ['left_ankle', [31.39128875732422, 412.1910095214844]], ['right_ankle', [36.37403106689453, 419.1715087890625]]]

# %% [markdown]
# #### Distance Formula ####

# %%
def closest_distance(point1, point2):
    cd = np.linalg.norm(point1 - point2)
    return cd

# %% [markdown]
# #### Find Closest Person function ####

# %%
def find_closest_person(previous_data, current_data):

    ## starting with first person from next file
    for c_person in current_data:
        new_person = ''
        min_distance = float('inf')
        cr_right_hip = None
        cr_left_hip = None

        ## gather coordinates of both right & left hip (current file)
        for part in c_person:
            if part[0] == 'right_hip':
                cr_right_hip = np.array(part[1])
            elif part[0] == 'left_hip':
                cr_left_hip = np.array(part[1])

        ## looping through each person from previous file
        for p_person in previous_data:
            pv_right_hip = None
            pv_left_hip = None

            ## gathering coordinates of both right & left hip (previous file)
            for part in p_person:
                if part[0] == 'right_hip':
                    pv_right_hip = np.array(part[1])
                elif part[0] == 'left_hip':
                    pv_left_hip = np.array(part[1])
            
            if cr_right_hip is not None and cr_left_hip is not None and pv_right_hip is not None and pv_left_hip is not None:
                distance = closest_distance(cr_right_hip, pv_right_hip) + closest_distance(cr_left_hip, pv_left_hip)

            ## finding which person has minimum distance
            if distance < min_distance:
                min_distance = distance
                new_person = p_person[0]

        ## assigning new person to current data
        c_person[0] = new_person

# %% [markdown]
# ### TESTING function ###

# %% [markdown]
# #### load current & previous data ####

# %%
# Load the JSON file
with open('./densepose/txt/ballet/-5Yp-vToI2E_016_0003.json', 'r') as f:
    curr_data = json.load(f)

# %%
# Load the JSON file
with open('./densepose/txt/ballet/-5Yp-vToI2E_016_0002.json', 'r') as f:
    prev_data = json.load(f)

# %%
for person in curr_data:
    print(person[0])
# Out:
# person0
# person1
# person2
# person3
# person4
# person5

# %%
for person in prev_data:
    print(person)
# Out:
# ['person0', ['nose', [417.4290771484375, 171.84947204589844]], ['left_eye', [429.3904113769531, 162.8577117919922]], ['right_eye', [417.4290771484375, 162.8577117919922]], ['left_ear', [457.3002014160156, 176.84487915039062]], ['right_ear', [416.4322814941406, 173.84762573242188]], ['left_shoulder', [494.1809997558594, 236.78988647460938]], ['right_shoulder', [404.470947265625, 233.79263305664062]], ['left_elbow', [561.9619140625, 295.7358093261719]], ['right_elbow', [358.619140625, 271.7578125]], ['left_wrist', [480.2261047363281, 319.71380615234375]], ['right_wrist', [432.3807373046875, 304.7275695800781]], ['left_hip', [483.2164306640625, 354.6817321777344]], ['right_hip', [425.4032897949219, 353.6826477050781]], ['left_knee', [520.0972290039062, 433.6093444824219]], ['right_knee', [368.5869140625, 451.59283447265625]], ['left_ankle', [494.1809997558594, 578.4764404296875]], ['right_ankle', [426.4000549316406, 537.5140380859375]]]
# ['person1', ['nose', [216.15411376953125, 173.7090301513672]], ['left_eye', [224.13616943359375, 166.72215270996094]], ['right_eye', [216.15411376953125, 166.72215270996094]], ['left_ear', [255.06661987304688, 171.7127685546875]], ['right_ear', [255.06661987304688, 172.71090698242188]], ['left_shoulder', [302.9589538574219, 232.59841918945312]], ['right_shoulder', [212.1630859375, 235.59278869628906]], ['left_elbow', [360.828857421875, 271.5252990722656]], ['right_elbow', [198.19448852539062, 300.470947265625]], ['left_wrist', [297.9701843261719, 318.43719482421875]], ['right_wrist', [252.0733642578125, 317.4390563964844]], ['left_hip', [293.9791564941406, 369.3415832519531]], ['right_hip', [232.11822509765625, 367.3453369140625]], ['left_knee', [307.94775390625, 475.1428527832031]], ['right_knee', [173.25054931640625, 462.167236328125]], ['left_ankle', [310.9410095214844, 587.9310302734375]], ['right_ankle', [221.14288330078125, 543.015380859375]]]
# ['person2', ['nose', [607.651611328125, 202.4984893798828]], ['left_eye', [617.6339721679688, 192.51235961914062]], ['right_eye', [608.6498413085938, 192.51235961914062]], ['left_ear', [643.5881958007812, 204.4957275390625]], ['right_ear', [646.5828857421875, 204.4957275390625]], ['left_shoulder', [687.5106201171875, 266.40972900390625]], ['right_shoulder', [602.6604614257812, 268.4069519042969]], ['left_elbow', [732.4312744140625, 313.34454345703125]], ['right_elbow', [559.7362670898438, 294.37091064453125]], ['left_wrist', [666.547607421875, 344.3015441894531]], ['right_wrist', [617.6339721679688, 329.3223571777344]], ['left_hip', [677.5282592773438, 391.23638916015625]], ['right_hip', [627.6163940429688, 393.2336120605469]], ['left_knee', [703.482421875, 495.0921325683594]], ['right_knee', [583.6939086914062, 484.1073913574219]], ['left_ankle', [681.5211791992188, 568.989501953125]], ['right_ankle', [653.570556640625, 548.0186157226562]]]
# ['person3', ['nose', [786.4564819335938, 201.50279235839844]], ['left_eye', [797.4168090820312, 193.5054168701172]], ['right_eye', [783.4673461914062, 193.5054168701172]], ['left_ear', [823.3229370117188, 202.50247192382812]], ['right_ear', [779.4817504882812, 209.5001678466797]], ['left_shoulder', [861.1857299804688, 265.4818115234375]], ['right_shoulder', [778.4853515625, 271.4798278808594]], ['left_elbow', [887.0918579101562, 331.4601745605469]], ['right_elbow', [729.6622924804688, 312.4664001464844]], ['left_wrist', [836.2760009765625, 359.45098876953125]], ['right_wrist', [797.4168090820312, 351.45361328125]], ['left_hip', [844.2471313476562, 385.44244384765625]], ['right_hip', [794.4276123046875, 385.44244384765625]], ['left_knee', [858.196533203125, 473.4136047363281]], ['right_knee', [762.5431518554688, 469.4149169921875]], ['left_ankle', [877.1279907226562, 556.3863525390625]], ['right_ankle', [829.30126953125, 552.3876953125]]]
# ['person4', ['nose', [876.6163330078125, 337.9047546386719]], ['left_eye', [879.5718994140625, 337.9047546386719]], ['right_eye', [873.6607666015625, 337.9047546386719]], ['left_ear', [890.4088745117188, 337.9047546386719]], ['right_ear', [889.4237060546875, 337.9047546386719]], ['left_shoulder', [905.1865844726562, 369.83154296875]], ['right_shoulder', [866.7645263671875, 363.8452453613281]], ['left_elbow', [913.0680541992188, 405.7491760253906]], ['right_elbow', [857.8978881835938, 404.75146484375]], ['left_wrist', [907.156982421875, 420.71484375]], ['right_wrist', [857.8978881835938, 352.87042236328125]], ['left_hip', [891.39404296875, 435.6805419921875]], ['right_hip', [867.7496948242188, 431.689697265625]], ['left_knee', [889.4237060546875, 484.5684509277344]], ['right_knee', [867.7496948242188, 479.57989501953125]], ['left_ankle', [881.542236328125, 554.4083251953125]], ['right_ankle', [878.586669921875, 554.4083251953125]]]
# ['person5', ['nose', [0.5106872320175171, 332.3782958984375]], ['left_eye', [0.5106872320175171, 332.3782958984375]], ['right_eye', [45.2339973449707, 431.44097900390625]], ['left_ear', [0.5106872320175171, 332.3782958984375]], ['right_ear', [0.5106872320175171, 332.3782958984375]], ['left_shoulder', [2.498389959335327, 338.32208251953125]], ['right_shoulder', [0.5106872320175171, 332.3782958984375]], ['left_elbow', [8.461498260498047, 381.9096374511719]], ['right_elbow', [9.455349922180176, 383.8908996582031]], ['left_wrist', [31.320079803466797, 412.6190490722656]], ['right_wrist', [31.320079803466797, 412.6190490722656]], ['left_hip', [0.5106872320175171, 332.3782958984375]], ['right_hip', [0.5106872320175171, 332.3782958984375]], ['left_knee', [6.473795413970947, 378.937744140625]], ['right_knee', [2.498389959335327, 338.32208251953125]], ['left_ankle', [32.31393051147461, 412.6190490722656]], ['right_ankle', [36.289337158203125, 419.5534362792969]]]

# %% [markdown]
# #### testing function ####

# %%
## print statement is for print each step in iteration

## starting with first person from next file
for c_person in curr_data:
    new_person = ''
    min_distance = float('inf')
    cr_right_hip = None
    cr_left_hip = None
    print('############################################')
    print('TESTING PERSON: ', c_person[0])
    print('############################################')

    ## gather coordinates of both right & left hip (current file)
    for part in c_person:
        if part[0] == 'right_hip':
            cr_right_hip = np.array(part[1])
        elif part[0] == 'left_hip':
            cr_left_hip = np.array(part[1])

    ## looping through each person from previous file
    for p_person in prev_data:
        pv_right_hip = None
        pv_left_hip = None
        print('COMPARING TESTING PERSON TO: ', p_person[0])

        ## gathering coordinates of both right & left hip (previous file)
        for part in p_person:
            if part[0] == 'right_hip':
                pv_right_hip = np.array(part[1])
            elif part[0] == 'left_hip':
                pv_left_hip = np.array(part[1])
            
        if cr_right_hip is not None and cr_left_hip is not None and pv_right_hip is not None and pv_left_hip is not None:
            distance = closest_distance(cr_right_hip, pv_right_hip) + closest_distance(cr_left_hip, pv_left_hip)

        print('DISTANCE BETWEEN: ', distance)

        ## finding which person has minimum distance
        if distance < min_distance:
            min_distance = distance
            new_person = p_person[0]

        print('CLOSEST PERSON: ', new_person)
        print('-----------------------')

    ## assigning new person to current data
    c_person[0] = new_person
# Out:
# ############################################
# TESTING PERSON:  person0
# ############################################
# COMPARING TESTING PERSON TO:  person0
# DISTANCE BETWEEN:  408.5701748375832
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person1
# DISTANCE BETWEEN:  26.780802889360775
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person2
# DISTANCE BETWEEN:  806.3120667687624
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person3
# DISTANCE BETWEEN:  1138.745386096233
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person4
# DISTANCE BETWEEN:  1265.9864386293166
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person5
# DISTANCE BETWEEN:  504.05154363357474
# CLOSEST PERSON:  person1
# -----------------------
# ############################################
# TESTING PERSON:  person1
# ############################################
# COMPARING TESTING PERSON TO:  person0
# DISTANCE BETWEEN:  24.139279526186733
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person1
# DISTANCE BETWEEN:  361.5236025597686
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person2
# DISTANCE BETWEEN:  427.6246745001493
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person3
# DISTANCE BETWEEN:  756.1406523317014
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person4
# DISTANCE BETWEEN:  889.1768394214033
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person5
# DISTANCE BETWEEN:  885.5189765370626
# CLOSEST PERSON:  person0
# -----------------------
# ############################################
# TESTING PERSON:  person2
# ############################################
# COMPARING TESTING PERSON TO:  person0
# DISTANCE BETWEEN:  380.92164991027835
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person1
# DISTANCE BETWEEN:  757.7710911859092
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person2
# DISTANCE BETWEEN:  23.501349362107447
# CLOSEST PERSON:  person2
# -----------------------
# COMPARING TESTING PERSON TO:  person3
# DISTANCE BETWEEN:  356.3395107588883
# CLOSEST PERSON:  person2
# -----------------------
# COMPARING TESTING PERSON TO:  person4
# DISTANCE BETWEEN:  484.67073992556016
# CLOSEST PERSON:  person2
# -----------------------
# COMPARING TESTING PERSON TO:  person5
# DISTANCE BETWEEN:  1286.8099237910646
# CLOSEST PERSON:  person2
# -----------------------
# ############################################
# TESTING PERSON:  person3
# ############################################
# COMPARING TESTING PERSON TO:  person0
# DISTANCE BETWEEN:  708.5015988988994
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person1
# DISTANCE BETWEEN:  1089.0223269082844
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person2
# DISTANCE BETWEEN:  310.1480893924844
# CLOSEST PERSON:  person2
# -----------------------
# COMPARING TESTING PERSON TO:  person3
# DISTANCE BETWEEN:  24.70924711651795
# CLOSEST PERSON:  person3
# -----------------------
# COMPARING TESTING PERSON TO:  person4
# DISTANCE BETWEEN:  176.8380297521739
# CLOSEST PERSON:  person3
# -----------------------
# COMPARING TESTING PERSON TO:  person5
# DISTANCE BETWEEN:  1616.898436719436
# CLOSEST PERSON:  person3
# -----------------------
# ############################################
# TESTING PERSON:  person4
# ############################################
# COMPARING TESTING PERSON TO:  person0
# DISTANCE BETWEEN:  862.0368038212755
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person1
# DISTANCE BETWEEN:  1236.4394142644603
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person2
# DISTANCE BETWEEN:  458.33657327004374
# CLOSEST PERSON:  person2
# -----------------------
# COMPARING TESTING PERSON TO:  person3
# DISTANCE BETWEEN:  154.24845356198557
# CLOSEST PERSON:  person3
# -----------------------
# COMPARING TESTING PERSON TO:  person4
# DISTANCE BETWEEN:  4.717469364667799
# CLOSEST PERSON:  person4
# -----------------------
# COMPARING TESTING PERSON TO:  person5
# DISTANCE BETWEEN:  1766.2637378209715
# CLOSEST PERSON:  person4
# -----------------------
# ############################################
# TESTING PERSON:  person5
# ############################################
# COMPARING TESTING PERSON TO:  person0
# DISTANCE BETWEEN:  906.3559026530193
# CLOSEST PERSON:  person0
# -----------------------
# COMPARING TESTING PERSON TO:  person1
# DISTANCE BETWEEN:  527.4159667620219
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person2
# DISTANCE BETWEEN:  1307.1724123137847
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person3
# DISTANCE BETWEEN:  1638.7368557602558
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person4
# DISTANCE BETWEEN:  1767.2268056160133
# CLOSEST PERSON:  person1
# -----------------------
# COMPARING TESTING PERSON TO:  person5
# DISTANCE BETWEEN:  4.30852380812525
# CLOSEST PERSON:  person5
# -----------------------

# %% [markdown]
# #### comparing new updated data ####

# %%
for person in curr_data:
    print(person)
# Out:
# ['person1', ['nose', [206.48001098632812, 162.3255615234375]], ['left_eye', [215.44972229003906, 154.33399963378906]], ['right_eye', [206.48001098632812, 154.33399963378906]], ['left_ear', [245.3487548828125, 162.3255615234375]], ['right_ear', [244.3521270751953, 163.3245086669922]], ['left_shoulder', [291.1939697265625, 223.26119995117188]], ['right_shoulder', [202.49346923828125, 223.26119995117188]], ['left_elbow', [350.9920349121094, 261.2210998535156]], ['right_elbow', [187.5439453125, 292.18841552734375]], ['left_wrist', [404.810302734375, 289.1915588378906]], ['right_wrist', [241.3622283935547, 309.17047119140625]], ['left_hip', [280.2309875488281, 363.1134948730469]], ['right_hip', [220.43289184570312, 367.1092834472656]], ['left_knee', [303.153564453125, 475.9942932128906]], ['right_knee', [172.5944366455078, 460.01116943359375]], ['left_ankle', [313.1199035644531, 576.8877563476562]], ['right_ankle', [216.44635009765625, 554.9109497070312]]]
# ['person0', ['nose', [410.4708557128906, 166.41331481933594]], ['left_eye', [422.4444885253906, 158.4152374267578]], ['right_eye', [410.4708557128906, 157.4154815673828]], ['left_ear', [448.3873596191406, 168.412841796875]], ['right_ear', [410.4708557128906, 166.41331481933594]], ['left_shoulder', [486.30389404296875, 231.3976593017578]], ['right_shoulder', [395.5038146972656, 225.39910888671875]], ['left_elbow', [553.1566772460938, 288.3839416503906]], ['right_elbow', [351.6004638671875, 263.38995361328125]], ['left_wrist', [468.3434143066406, 309.3788757324219]], ['right_wrist', [420.4488830566406, 295.38226318359375]], ['left_hip', [470.3390197753906, 349.3692626953125]], ['right_hip', [415.4598693847656, 351.3687744140625]], ['left_knee', [485.30609130859375, 452.3444519042969]], ['right_knee', [370.5587463378906, 456.3434753417969]], ['left_ankle', [518.2335815429688, 556.3193969726562]], ['right_ankle', [419.4510803222656, 550.3208618164062]]]
# ['person2', ['nose', [599.4203491210938, 198.0174102783203]], ['left_eye', [609.384521484375, 191.0225067138672]], ['right_eye', [600.416748046875, 191.0225067138672]], ['left_ear', [636.2877197265625, 200.0159454345703]], ['right_ear', [638.280517578125, 201.0152130126953]], ['left_shoulder', [672.1586303710938, 258.97296142578125]], ['right_shoulder', [589.4562377929688, 264.96856689453125]], ['left_elbow', [720.98291015625, 307.937255859375]], ['right_elbow', [549.5996704101562, 288.9510803222656]], ['left_wrist', [657.21240234375, 337.9153747558594]], ['right_wrist', [608.3880615234375, 323.92559814453125]], ['left_hip', [667.176513671875, 386.87969970703125]], ['right_hip', [615.3629760742188, 393.87457275390625]], ['left_knee', [695.0761108398438, 490.80389404296875]], ['right_knee', [575.5064086914062, 478.8126525878906]], ['left_ankle', [676.144287109375, 590.7310180664062]], ['right_ankle', [651.23388671875, 549.7609252929688]]]
# ['person3', ['nose', [775.3849487304688, 193.22845458984375]], ['left_eye', [786.373046875, 184.24578857421875]], ['right_eye', [775.3849487304688, 184.24578857421875]], ['left_ear', [810.3471069335938, 197.2207489013672]], ['right_ear', [771.3892822265625, 198.2188262939453]], ['left_shoulder', [850.3038330078125, 261.09747314453125]], ['right_shoulder', [765.395751953125, 263.0936279296875]], ['left_elbow', [879.2724609375, 324.97418212890625]], ['right_elbow', [719.4454956054688, 308.0069274902344]], ['left_wrist', [827.3287353515625, 356.91253662109375]], ['right_wrist', [787.3719482421875, 347.92987060546875]], ['left_hip', [834.3211669921875, 385.856689453125]], ['right_hip', [780.3795166015625, 380.8663024902344]], ['left_knee', [836.3189697265625, 476.681396484375]], ['right_knee', [761.4000854492188, 468.6968078613281]], ['left_ankle', [841.3135986328125, 570.5003051757812]], ['right_ankle', [796.3622436523438, 545.5484619140625]]]
# ['person4', ['nose', [864.1947021484375, 335.63397216796875]], ['left_eye', [870.17626953125, 335.63397216796875]], ['right_eye', [864.1947021484375, 334.634765625]], ['left_ear', [889.1178588867188, 337.6324157714844]], ['right_ear', [890.1148071289062, 335.63397216796875]], ['left_shoulder', [904.07177734375, 370.6068115234375]], ['right_shoulder', [861.2039184570312, 364.6114501953125]], ['left_elbow', [911.05029296875, 408.5773010253906]], ['right_elbow', [852.2315673828125, 400.58349609375]], ['left_wrist', [906.0656127929688, 420.5679626464844]], ['right_wrist', [863.1978149414062, 415.5718688964844]], ['left_hip', [890.1148071289062, 436.5555419921875]], ['right_hip', [865.191650390625, 433.5578918457031]], ['left_knee', [888.1209716796875, 490.51361083984375]], ['right_knee', [867.1854858398438, 486.5167236328125]], ['left_ankle', [887.1240234375, 554.4639282226562]], ['right_ankle', [879.1486206054688, 557.4616088867188]]]
# ['person5', ['nose', [1.5709651708602905, 334.2535705566406]], ['left_eye', [43.83826446533203, 427.6568908691406]], ['right_eye', [42.85530471801758, 427.6568908691406]], ['left_ear', [1.5709651708602905, 334.2535705566406]], ['right_ear', [1.5709651708602905, 334.2535705566406]], ['left_shoulder', [3.536886215209961, 339.2218322753906]], ['right_shoulder', [1.5709651708602905, 334.2535705566406]], ['left_elbow', [13.366490364074707, 382.9425354003906]], ['right_elbow', [12.383530616760254, 382.9425354003906]], ['left_wrist', [33.025699615478516, 409.7711486816406]], ['right_wrist', [34.99161911010742, 412.7521057128906]], ['left_hip', [1.5709651708602905, 334.2535705566406]], ['right_hip', [1.5709651708602905, 334.2535705566406]], ['left_knee', [3.536886215209961, 339.2218322753906]], ['right_knee', [3.536886215209961, 339.2218322753906]], ['left_ankle', [35.97458267211914, 412.7521057128906]], ['right_ankle', [39.90642166137695, 419.7076721191406]]]

# %%
for person in prev_data:
    print(person)
# Out:
# ['person0', ['nose', [417.4290771484375, 171.84947204589844]], ['left_eye', [429.3904113769531, 162.8577117919922]], ['right_eye', [417.4290771484375, 162.8577117919922]], ['left_ear', [457.3002014160156, 176.84487915039062]], ['right_ear', [416.4322814941406, 173.84762573242188]], ['left_shoulder', [494.1809997558594, 236.78988647460938]], ['right_shoulder', [404.470947265625, 233.79263305664062]], ['left_elbow', [561.9619140625, 295.7358093261719]], ['right_elbow', [358.619140625, 271.7578125]], ['left_wrist', [480.2261047363281, 319.71380615234375]], ['right_wrist', [432.3807373046875, 304.7275695800781]], ['left_hip', [483.2164306640625, 354.6817321777344]], ['right_hip', [425.4032897949219, 353.6826477050781]], ['left_knee', [520.0972290039062, 433.6093444824219]], ['right_knee', [368.5869140625, 451.59283447265625]], ['left_ankle', [494.1809997558594, 578.4764404296875]], ['right_ankle', [426.4000549316406, 537.5140380859375]]]
# ['person1', ['nose', [216.15411376953125, 173.7090301513672]], ['left_eye', [224.13616943359375, 166.72215270996094]], ['right_eye', [216.15411376953125, 166.72215270996094]], ['left_ear', [255.06661987304688, 171.7127685546875]], ['right_ear', [255.06661987304688, 172.71090698242188]], ['left_shoulder', [302.9589538574219, 232.59841918945312]], ['right_shoulder', [212.1630859375, 235.59278869628906]], ['left_elbow', [360.828857421875, 271.5252990722656]], ['right_elbow', [198.19448852539062, 300.470947265625]], ['left_wrist', [297.9701843261719, 318.43719482421875]], ['right_wrist', [252.0733642578125, 317.4390563964844]], ['left_hip', [293.9791564941406, 369.3415832519531]], ['right_hip', [232.11822509765625, 367.3453369140625]], ['left_knee', [307.94775390625, 475.1428527832031]], ['right_knee', [173.25054931640625, 462.167236328125]], ['left_ankle', [310.9410095214844, 587.9310302734375]], ['right_ankle', [221.14288330078125, 543.015380859375]]]
# ['person2', ['nose', [607.651611328125, 202.4984893798828]], ['left_eye', [617.6339721679688, 192.51235961914062]], ['right_eye', [608.6498413085938, 192.51235961914062]], ['left_ear', [643.5881958007812, 204.4957275390625]], ['right_ear', [646.5828857421875, 204.4957275390625]], ['left_shoulder', [687.5106201171875, 266.40972900390625]], ['right_shoulder', [602.6604614257812, 268.4069519042969]], ['left_elbow', [732.4312744140625, 313.34454345703125]], ['right_elbow', [559.7362670898438, 294.37091064453125]], ['left_wrist', [666.547607421875, 344.3015441894531]], ['right_wrist', [617.6339721679688, 329.3223571777344]], ['left_hip', [677.5282592773438, 391.23638916015625]], ['right_hip', [627.6163940429688, 393.2336120605469]], ['left_knee', [703.482421875, 495.0921325683594]], ['right_knee', [583.6939086914062, 484.1073913574219]], ['left_ankle', [681.5211791992188, 568.989501953125]], ['right_ankle', [653.570556640625, 548.0186157226562]]]
# ['person3', ['nose', [786.4564819335938, 201.50279235839844]], ['left_eye', [797.4168090820312, 193.5054168701172]], ['right_eye', [783.4673461914062, 193.5054168701172]], ['left_ear', [823.3229370117188, 202.50247192382812]], ['right_ear', [779.4817504882812, 209.5001678466797]], ['left_shoulder', [861.1857299804688, 265.4818115234375]], ['right_shoulder', [778.4853515625, 271.4798278808594]], ['left_elbow', [887.0918579101562, 331.4601745605469]], ['right_elbow', [729.6622924804688, 312.4664001464844]], ['left_wrist', [836.2760009765625, 359.45098876953125]], ['right_wrist', [797.4168090820312, 351.45361328125]], ['left_hip', [844.2471313476562, 385.44244384765625]], ['right_hip', [794.4276123046875, 385.44244384765625]], ['left_knee', [858.196533203125, 473.4136047363281]], ['right_knee', [762.5431518554688, 469.4149169921875]], ['left_ankle', [877.1279907226562, 556.3863525390625]], ['right_ankle', [829.30126953125, 552.3876953125]]]
# ['person4', ['nose', [876.6163330078125, 337.9047546386719]], ['left_eye', [879.5718994140625, 337.9047546386719]], ['right_eye', [873.6607666015625, 337.9047546386719]], ['left_ear', [890.4088745117188, 337.9047546386719]], ['right_ear', [889.4237060546875, 337.9047546386719]], ['left_shoulder', [905.1865844726562, 369.83154296875]], ['right_shoulder', [866.7645263671875, 363.8452453613281]], ['left_elbow', [913.0680541992188, 405.7491760253906]], ['right_elbow', [857.8978881835938, 404.75146484375]], ['left_wrist', [907.156982421875, 420.71484375]], ['right_wrist', [857.8978881835938, 352.87042236328125]], ['left_hip', [891.39404296875, 435.6805419921875]], ['right_hip', [867.7496948242188, 431.689697265625]], ['left_knee', [889.4237060546875, 484.5684509277344]], ['right_knee', [867.7496948242188, 479.57989501953125]], ['left_ankle', [881.542236328125, 554.4083251953125]], ['right_ankle', [878.586669921875, 554.4083251953125]]]
# ['person5', ['nose', [0.5106872320175171, 332.3782958984375]], ['left_eye', [0.5106872320175171, 332.3782958984375]], ['right_eye', [45.2339973449707, 431.44097900390625]], ['left_ear', [0.5106872320175171, 332.3782958984375]], ['right_ear', [0.5106872320175171, 332.3782958984375]], ['left_shoulder', [2.498389959335327, 338.32208251953125]], ['right_shoulder', [0.5106872320175171, 332.3782958984375]], ['left_elbow', [8.461498260498047, 381.9096374511719]], ['right_elbow', [9.455349922180176, 383.8908996582031]], ['left_wrist', [31.320079803466797, 412.6190490722656]], ['right_wrist', [31.320079803466797, 412.6190490722656]], ['left_hip', [0.5106872320175171, 332.3782958984375]], ['right_hip', [0.5106872320175171, 332.3782958984375]], ['left_knee', [6.473795413970947, 378.937744140625]], ['right_knee', [2.498389959335327, 338.32208251953125]], ['left_ankle', [32.31393051147461, 412.6190490722656]], ['right_ankle', [36.289337158203125, 419.5534362792969]]]

# %% [markdown]
# #### plotting new charts ####

# %%
def get_ppl_info(data):
    people = []
    j = data

    for i,person in enumerate(j):
        #Set up list to collect person's body location
        person_i = []
        count = 0

        #add each body part position to the list
        for body_part in person:
            count+=1
            if count == 1: continue
            else: person_i.append(body_part[1])

        #Append entire list to list of people
        people.append(person_i)

    return people

# %%
def reorder_people(data):
    ''' Input a list of people where the person number has been updated to the correctly identified person, but the
    order of the people is still out of order.  This function will correctly reorder the list of people for
     proper plotting '''
    updated_people = [0 for i in range(len(data))]
    for person in data:
        person_index = int(person[0][-1]) #Pulls out the digit number of the person
        updated_people[person_index] = person #Place the person in the correct order
    return updated_people

# %%
curr_data = reorder_people(curr_data)

# %%
data1 = get_ppl_info(curr_data)

# %%
data2 = get_ppl_info(prev_data)

# %% [markdown]
# #### graph ####

# %%
plot_body_positions(data1, figsize=(6,3))

# %%
plot_body_positions(data2, figsize=(6,3))
